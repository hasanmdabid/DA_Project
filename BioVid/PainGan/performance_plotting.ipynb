# %%
""""
This Functon will plot the Epoch vs Losses (Discriminator and generator)
1st we will take the average of d_loss_real , d_loss_fake, and g_loss
2nd we will plot them in the graphs
"""
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
data = pd.read_csv('/home/abidhasan/Documents/PAINGAN/results/loss_record/biovid_500_D_and_G_loss.csv', sep=';')

data = data.drop(['gen_activation',' batch_per_epoch'], axis=1)
df = data.groupby(by=[" epochs"]).mean()
sns.set(style="whitegrid")

df.plot(figsize=(12, 8))

plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.title('Plot of D_loss and G_loss', fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)


plt.savefig('/home/abidhasan/Documents/PAINGAN/picture/biovid_PAINCGAN_performance.eps', format = 'eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data = pd.read_csv('/home/abidhasan/Documents/PAINGAN/results/loss_record/painmonit_2000_D_and_G_loss.csv', sep=';')

data = data.drop(['gen_activation',' batch_per_epoch'], axis=1)
df = data.groupby(by=[" epochs"]).mean()
sns.set(style="whitegrid")
# Create the bar plot
#plt.figure(figsize=(12, 8))  # Adjust the figure size if needed

df.plot(figsize=(12,8))
plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.title('Plot of D_loss and G_loss', fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

plt.savefig('/home/abidhasan/Documents/PAINGAN/picture/painmonit_PAINCGAN_performance.eps', format = 'eps',  bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
df.head(5)
# Out:
#           d_loss_real   d_loss_fake    g_loss
#  epochs
# 0            0.670626      0.695105  0.691431
# 1            0.636428      0.738676  0.653569
# 2            0.626348      0.801126  0.603235
# 3            0.627637      0.768829  0.628892
# 4            0.647190      0.770611  0.628030

# %%
df_log = df.apply(np.log)

df_log.plot()
plt.xlabel('Epochs')
plt.ylabel('Logarithm of Values')
plt.title('Plot of Logarithm of D_loss and G_loss on x-axis')
plt.legend()
plt.show()
#plt.savefig('HARCGAN_performance_100Epochs.jpg')

# %%
data = pd.read_csv('/home/abidhasan/Documents/DEAPGAN/results/loss_record/arousal_D_and_G_loss.csv', sep=';')

data = data.drop(['gen_activation',' batch_per_epoch'], axis=1)
#data = data.drop(['g_loss'], axis=1)
df = data.groupby(by=[" epochs"]).mean()
df.plot()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Plot of D_loss and G_loss on x-axis')
plt.legend()
plt.show()
